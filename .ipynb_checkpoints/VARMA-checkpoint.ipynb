# %% [markdown]
# $y_{t} = \sum \limits _{k=1}^d A_k y_{t-k} + \epsilon_{t}$

# %% [raw]
# To estimate model candidates ,we use some information criteria such as AIC and cross-correlation

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Data/EU/full_data.csv')

# %%
df.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
for i in df.columns.values[1:]:
    print(i)
    fig = plt.figure(figsize = (8, 1.5))
    ax = fig.add_axes([0.10, 0.22, 0.85, 0.75])
    plt.plot(df[i].values, color = "black", linewidth = 0.5)
    plt.ylabel(i)
    plt.xlabel("Day")
    plt.show()
# Out:
# y2 yield
# y5 yield
# y10 yield
# inflation_rate
# unemployment_rate
# gdp_growth_rate
# debt_rate_to_GDP
# GAX_index
# GAX_volume
# eur_usd

# %%
df.describe()
# Out:
#           y2 yield     y5 yield    y10 yield  inflation_rate  \
# count  5264.000000  5264.000000  5264.000000     5264.000000
# mean      2.075562     2.529700     2.529700        1.682067
# std       2.144015     1.743413     1.743413        0.944434
# min      -0.566200    -0.310600    -0.310600       -0.600000
# 25%      -0.023100     0.569900     0.569900        1.100000
# 50%       2.075700     2.893100     2.893100        1.900000
# 75%       3.584400     3.876500     3.876500        2.300000
# max      13.558700     5.944600     5.944600        4.100000
#
#        unemployment_rate  gdp_growth_rate  debt_rate_to_GDP     GAX_index  \
# count        5264.000000      5264.000000       5264.000000   5264.000000
# mean            9.329846         1.072359         80.159943   7597.769881
# std             1.340834         2.607499         10.171719   2966.915702
# min             7.254401       -14.600000         65.972000   2202.959961
# 25%             8.383344         0.700000         69.669000   5343.077393
# 50%             9.082829         1.600000         83.240000   6948.534912
# 75%            10.195064         2.300000         90.142000  10001.719971
# max            12.099649         4.500000         97.319000  13789.000000
#
#          GAX_volume      eur_usd
# count  5.264000e+03  5264.000000
# mean   1.068632e+08     1.206563
# std    5.077497e+07     0.164365
# min    0.000000e+00     0.827300
# 25%    7.672905e+07     1.108500
# 50%    9.778915e+07     1.216100
# 75%    1.258558e+08     1.327400
# max    5.101956e+08     1.598800

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df['eur_usd'].values)
print("ADF Statistics", result[0])
print("P value", result[1])
# Out:
# ADF Statistics -1.8173459726475676
# P value 0.37188453783985914

# %%
## Differencing to be done
np.log(values)
df['y2 yield'].shift(-30)
# Out:
# 0       4.5451
# 1       4.5451
# 2       4.5451
# 3       4.5451
# 4       4.5451
#          ...
# 5408       NaN
# 5409       NaN
# 5410       NaN
# 5411       NaN
# 5412       NaN
# Name: y2 yield, Length: 5264, dtype: float64

# %% [markdown]
# For a Time series to be stationary, its ADCF test should have:
#
# 1. p-value to be low (according to the null hypothesis)
#
# 2. The critical values at 1%,5%,10% confidence intervals should be as close as possible to the Test Statistics From the above ADCF test result, we see that p-value(at max can be.0) is very negligible. Also critical values are very close to the Test Statistics. Hence, we can safely say that our Time Series at the moment is stationary

# %%
for i in df.columns.values[1:]:
    print(f'Results of Dickey Fuller Test on variable {i}:')
    dftest = adfuller(df[i], autolag='AIC')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    print("***************************************************")
# Out:
# Results of Dickey Fuller Test on variable y2 yield:
# Test Statistic                   -3.324864
# p-value                           0.013803
# #Lags Used                       22.000000
# Number of Observations Used    5241.000000
# Critical Value (1%)              -3.431598
# Critical Value (5%)              -2.862092
# Critical Value (10%)             -2.567064
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable y5 yield:
# Test Statistic                   -1.387998
# p-value                           0.588016
# #Lags Used                       23.000000
# Number of Observations Used    5240.000000
# Critical Value (1%)              -3.431599
# Critical Value (5%)              -2.862092
# Critical Value (10%)             -2.567064
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable y10 yield:
# Test Statistic                   -1.387998
# p-value                           0.588016
# #Lags Used                       23.000000
# Number of Observations Used    5240.000000
# Critical Value (1%)              -3.431599
# Critical Value (5%)              -2.862092
# Critical Value (10%)             -2.567064
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable inflation_rate:
# Test Statistic                   -1.689905
# p-value                           0.436321
# #Lags Used                        0.000000
# Number of Observations Used    5263.000000
# Critical Value (1%)              -3.431593
# Critical Value (5%)              -2.862089
# Critical Value (10%)             -2.567062
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable unemployment_rate:
# Test Statistic                   -1.349773
# p-value                           0.606105
# #Lags Used                       25.000000
# Number of Observations Used    5238.000000
# Critical Value (1%)              -3.431599
# Critical Value (5%)              -2.862092
# Critical Value (10%)             -2.567064
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable gdp_growth_rate:
# Test Statistic                   -3.173952
# p-value                           0.021543
# #Lags Used                        0.000000
# Number of Observations Used    5263.000000
# Critical Value (1%)              -3.431593
# Critical Value (5%)              -2.862089
# Critical Value (10%)             -2.567062
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable debt_rate_to_GDP:
# Test Statistic                    0.118553
# p-value                           0.967305
# #Lags Used                        0.000000
# Number of Observations Used    5263.000000
# Critical Value (1%)              -3.431593
# Critical Value (5%)              -2.862089
# Critical Value (10%)             -2.567062
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable GAX_index:
# Test Statistic                   -0.697001
# p-value                           0.847525
# #Lags Used                        8.000000
# Number of Observations Used    5255.000000
# Critical Value (1%)              -3.431595
# Critical Value (5%)              -2.862090
# Critical Value (10%)             -2.567063
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable GAX_volume:
# Test Statistic                   -5.014364
# p-value                           0.000021
# #Lags Used                       29.000000
# Number of Observations Used    5234.000000
# Critical Value (1%)              -3.431600
# Critical Value (5%)              -2.862092
# Critical Value (10%)             -2.567064
# dtype: float64
# ***************************************************
# Results of Dickey Fuller Test on variable eur_usd:
# Test Statistic                   -1.817346
# p-value                           0.371885
# #Lags Used                       11.000000
# Number of Observations Used    5252.000000
# Critical Value (1%)              -3.431596
# Critical Value (5%)              -2.862090
# Critical Value (10%)             -2.567063
# dtype: float64
# ***************************************************

# %% [raw]
# It seems that eur_usd exchange rate, GAX index, y5_yield and y10_yield are nonstationary and GAX volume, y2 yield, gdp_growth_rate and GAX_volume are stationary. So we should use differencing to make the nonstationary data stationary.

# %% [raw]
# We choose the three stationary data y2 yield, gdp_growth_rate and GAX_volume to do preliminary experiements

# %%
def norm_cross_corr(set1, set2):
    return np.sum(set1 * set2) / (np.linalg.norm(set1) * np.linalg.norm(set2))

# %%
from sklearn import metrics
from scipy.stats import chi2_contingency
def calc_MI(x, y, bins):
    c_xy = np.histogram2d(x, y, bins)[0]
    g, p, dof, expected = chi2_contingency(c_xy, lambda_="log-likelihood")
    mi = 0.5 * g / c_xy.sum()
    return mi

# %%
def cal_corr(target):
    for v in df.columns[1:].values.tolist():
        if v == target:
            continue
        normed_cc = norm_cross_corr(df[v].values, df[target].values)
        mi = metrics.normalized_mutual_info_score(df[v].values, df[target].values)
        print(f"The normed cross correlation betwenn {target} and {v} is {normed_cc}")
        print(f"The mutual information betwenn {target} and {v} is {mi}")

# %%
cal_corr("eur_usd")
# Out:
# The normed cross correlation betwenn eur_usd and y2 yield is 0.6918864048669022
# The mutual information betwenn eur_usd and y2 yield is 0.7336163339973661
# The normed cross correlation betwenn eur_usd and y5 yield is 0.81764331698487
# The mutual information betwenn eur_usd and y5 yield is 0.733616333997366
# The normed cross correlation betwenn eur_usd and y10 yield is 0.81764331698487
# The mutual information betwenn eur_usd and y10 yield is 0.733616333997366
# The normed cross correlation betwenn eur_usd and inflation_rate is 0.8691275122691744
# The mutual information betwenn eur_usd and inflation_rate is 0.5152749141203643
# The normed cross correlation betwenn eur_usd and unemployment_rate is 0.9848155959250672
# The mutual information betwenn eur_usd and unemployment_rate is 0.7336163339973661
# The normed cross correlation betwenn eur_usd and gdp_growth_rate is 0.3570417140583901
# The mutual information betwenn eur_usd and gdp_growth_rate is 0.5486924021623899
# The normed cross correlation betwenn eur_usd and debt_rate_to_GDP is 0.9851318180485735
# The mutual information betwenn eur_usd and debt_rate_to_GDP is 0.6281232309111484
# The normed cross correlation betwenn eur_usd and GAX_index is 0.9185658486500248
# The mutual information betwenn eur_usd and GAX_index is 0.9624773023285873
# The normed cross correlation betwenn eur_usd and GAX_volume is 0.9216682441581486
# The mutual information betwenn eur_usd and GAX_volume is 0.9622412801286048
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received multiclass values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)

# %%
variables = ['eur_usd','y10 yield','GAX_index','debt_rate_to_GDP']

# %%
import numpy as np

def var_model(mat_Y, order_p, num_pred):
    """
    
    """
    
    N, T = mat_Y.shape
    time_lags = np.array(list(range(1, order_p + 1)))
    mat_Z = mat_Y[:, order_p :].T 
    mat_Q = np.zeros((T - order_p, N * order_p))
    for t in range(T - order_p):
        mat_Q[t, :] = mat_Y[:, t + order_p - time_lags].reshape([N * order_p])
    mat_A = np.matmul(np.matmul(np.linalg.inv(np.matmul(mat_Q.T, mat_Q)), mat_Q.T), mat_Z) 
    mat_Y_new = np.zeros((N, T + num_pred))
    mat_Y_new[:, : T] = mat_Y
    for t in range(num_pred):
        mat_Y_new[:, T+t] = np.matmul(mat_A.T, mat_Y_new[:, T + t - time_lags].reshape([N * order_p]))
    
    return mat_A, mat_Y_new[:, T :]

# %% [markdown]
# If we have $N$ dimension data with $T$ time steps and the AR order is $p$, we have $N*(Np)$ parameters for estimating. And one thing we should follow is that $Np\ll p$

# %%
import time
start = time.time()
def train(X, order_p=3, pred_steps=200, num_pred = 5):
    N, T = X.shape
    back_steps = T - pred_steps
    start_step = T - pred_steps
    mat_hat = np.zeros((N, pred_steps))
    for t in range(int(pred_steps / num_pred)):
        if t == 0:
            A, vec = var_model(X[:, 0 : t * num_pred + start_step], order_p, num_pred)
        else:
            A, vec = var_model(X[:, t * num_pred + start_step - back_steps 
                                 : t * num_pred + start_step], order_p, num_pred)
        if num_pred == 1:
            mat_hat[:, t] = vec.reshape(N)
        else:
            mat_hat[:, t * num_pred : (t + 1) * num_pred] = vec
        if (t + 1) % 40 == 0:
            print('The current prediction step is {}.'.format(t + 1))

    end = time.time()
    print('Running time: %d seconds'%(end - start))
    plt.style.use('ggplot')
    for i,d in enumerate(variables):
        fig = plt.figure(figsize = (10, 2))
    #     ax = fig.add_axes([0.13, 0.28, 0.85, 0.68])
        plt.plot(list(range(T - pred_steps, T)),X[i,  T - pred_steps:], color = "black", linewidth = 0.5)
        plt.plot(list(range(T - pred_steps, T)), 
                 mat_hat[i, :], color = "#e3120b", linewidth = 1.0)
        plt.xlabel("Days")
        plt.ylabel(d)
        ax.set_ylim([0, 65])
    return mat_hat

# %%
## Results that use non stationary variables

# %%
order_p=5
pred_steps=30
num_pred=3
variables = ['eur_usd','y10 yield','GAX_index','debt_rate_to_GDP']
mat_hat = train(df[variables].values.T, order_p=order_p, pred_steps=pred_steps, num_pred=num_pred)
# Out:
# Running time: 303 seconds

# %%
# Results that use statinary variables

# %%
variables = ['eur_usd','y2 yield','GAX_volume','gdp_growth_rate']
mat_hat = train(df[variables].values.T,order_p=order_p, pred_steps=pred_steps, num_pred=num_pred)
# Out:
# Running time: 305 seconds
